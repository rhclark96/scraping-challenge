# %% [markdown]
# # Module 11 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Extract all rows of data
rows = soup.find_all('tr', class_='data-row')
print(rows)
# Out:
# [<tr class="data-row">
# <td>2</td>
# <td>2012-08-16</td>
# <td>10</td>
# <td>155</td>
# <td>6</td>
# <td>-75.0</td>
# <td>739.0</td>
# </tr>, <tr class="data-row">
# <td>13</td>
# <td>2012-08-17</td>
# <td>11</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>740.0</td>
# </tr>, <tr class="data-row">
# <td>24</td>
# <td>2012-08-18</td>
# <td>12</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>741.0</td>
# </tr>, <tr class="data-row">
# <td>35</td>
# <td>2012-08-19</td>
# <td>13</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>732.0</td>
# </tr>, <tr class="data-row">
# <td>46</td>
# <td>2012-08-20</td>
# <td>14</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>740.0</td>
# </tr>, <tr class="data-row">
# <td>57</td>
# <td>2012-08-21</td>
# <td>15</td>
# <td>158</td>
# <td>6</td>
# <td>-78.0</td>
# <td>740.0</td>
# </tr>, <tr class="data-row">
# <td>68</td>
# <td>2012-08-22</td>
# <td>16</td>
# <td>158</td>
# <td>6</td>
# <td>-77.0</td>
# <td>740.0</td>
# ...

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
list_of_rows = []

# Loop through the scraped data to create a list of rows
for row in rows: 
    column_data = row.find_all('td')
    row_data = {
        "id":column_data[0].text.strip(),
        "terrestrial_date":column_data[1].text.strip(),
        "sol":column_data[2].text.strip(),
        "ls":column_data[3].text.strip(),
        "month":column_data[4].text.strip(),
        "min_temp":column_data[5].text.strip(),
        "pressure":column_data[6].text.strip()
    }
    list_of_rows.append(row_data)
    
print(list_of_rows)
# Out:
# [{'id': '2', 'terrestrial_date': '2012-08-16', 'sol': '10', 'ls': '155', 'month': '6', 'min_temp': '-75.0', 'pressure': '739.0'}, {'id': '13', 'terrestrial_date': '2012-08-17', 'sol': '11', 'ls': '156', 'month': '6', 'min_temp': '-76.0', 'pressure': '740.0'}, {'id': '24', 'terrestrial_date': '2012-08-18', 'sol': '12', 'ls': '156', 'month': '6', 'min_temp': '-76.0', 'pressure': '741.0'}, {'id': '35', 'terrestrial_date': '2012-08-19', 'sol': '13', 'ls': '157', 'month': '6', 'min_temp': '-74.0', 'pressure': '732.0'}, {'id': '46', 'terrestrial_date': '2012-08-20', 'sol': '14', 'ls': '157', 'month': '6', 'min_temp': '-74.0', 'pressure': '740.0'}, {'id': '57', 'terrestrial_date': '2012-08-21', 'sol': '15', 'ls': '158', 'month': '6', 'min_temp': '-78.0', 'pressure': '740.0'}, {'id': '68', 'terrestrial_date': '2012-08-22', 'sol': '16', 'ls': '158', 'month': '6', 'min_temp': '-77.0', 'pressure': '740.0'}, {'id': '79', 'terrestrial_date': '2012-08-23', 'sol': '17', 'ls': '159', 'month': '6', '
# ...

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
mars_data_df = pd.DataFrame(list_of_rows)

# %%
# Confirm DataFrame was created successfully
mars_data_df.head()
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
mars_data_df.dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
final_data = mars_data_df.astype({
    'terrestrial_date': 'datetime64[ns]', 
    'sol':'int32', 
    'ls':'int32', 
    'month':'int32',
    'min_temp':'float64',
    'pressure':'float64'
})

# %%
# Confirm type changes were successful by examining data types again
final_data.dtypes
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int32
# ls                           int32
# month                        int32
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
months = final_data['month'].nunique()
print(months)
# Out:
# 12

# %%
# 2. How many sols (Martian days) worth of data are there?
sols = final_data['sol'].count()
print(sols)
# Out:
# 1867

# %%
# 3. What is the average minimum temperature by month?
avg_temp_month = final_data.groupby('month')['min_temp'].mean()
avg_temp_month
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average minimum temperature by month
plt.bar(avg_temp_month.index, avg_temp_month, color = 'pink')
plt.xticks(avg_temp_month.index)
plt.xlabel("month")
plt.ylabel("Temperature in Celcius")
plt.title("Avg. Minimum Temperature by Month")
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location by sorting the previous graph
avg_temp_month.sort_values().plot(kind='bar', color='orange')
plt.xlabel("month")
plt.ylabel("Temperature in Celcius")
plt.title("Avg. Minimum Temperature by Month")
plt.show()

# %%
# 4. What is the average pressure by month?
avg_press_month = final_data.groupby('month')['pressure'].mean()
avg_press_month
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
plt.bar(avg_press_month.index, avg_press_month, color = 'lightgreen')
plt.xticks(avg_press_month.index)
plt.xlabel("month")
plt.ylabel("Atmospheric Pressure")
plt.title("Avg. Pressure by Month")
plt.show()

# %%
# Identify the lowest and highest pressure months in Curiosity's location by sorting the previous graph
avg_press_month.sort_values().plot(kind='bar', color = 'teal')
plt.xlabel("month")
plt.ylabel("Atmospheric Pressure")
plt.title("Avg. Pressure by Month")
plt.show()

# %%
# 5. How many terrestrial (Earth) days are there in a Martian year?
#Convert terrestrial dats into number of days since recording started
start_date = pd.to_datetime('2012-08-16')
final_data['number_of_days']= (final_data['terrestrial_date'] -start_date).dt.days
# Visually estimate the result by plotting the daily minimum temperature of each observation in the data set.
plt.plot(final_data['number_of_days'], final_data['min_temp'], color = 'mediumorchid')
plt.xlabel("Number of Terrestrial Days")
plt.ylabel("Temperature in Celcius")
plt.title("Minimum Temperature Over Time")
plt.show()

# %% [markdown]
# #### Minimum Temperature
#
# The lowest minimum temperatures recorded by the Curiosity rover were on average in the fifth and sixth months of the Martian year. On the other hand, the highest minimum temperatures recorded by the Curiosity rover wiere on average during the seveth to eleventh months of the Martian year. Overall, the minimum average temperature recorded by the Curiosity rover only varies by about 15 degrees Celcius throughout the year.

# %% [markdown]
# #### Atmospheric Pressure
#
# The lowest atmospheric pressure recorded by the Curiosity rover were on average in the second to fifth month of the Martian year. On the other hand, the highest minimum temperatures recorded by the Curiosity rover wiere on average during the ninth and tenth months of the Martian year. Overall, the minimum average atmospheric pressure recorded by the Curiosity rover only varies by about 150 Pascals throughout the year.

# %% [markdown]
# #### Year Length
#
# Based on the graph of average minimum temperature compared to the number of terrestrial days, it appears that the average minimum temperatures complete aproximately three cycles in seasonal temperature change, indicating that three Martian years have been completed. This occurs over 2000 terrestrial days, meaning that one Martian year is roughly 667 terrestrial days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
final_data.to_csv('Mars_Weather_Data.csv', index=True)

# %%
browser.quit()
